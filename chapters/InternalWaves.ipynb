# %% [markdown]
# # Internal Waves
#
# The objective of this notebook is to compile an inventory of internal waves at the shallow profiler sites.
# This analysis begins at the Oregon Slope Base site, working from a sequence of profiles beginning on January 1 2024.
# The reference document is `~/argosy/InternalWaves.md`.
