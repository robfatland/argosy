# %% [markdown]
# # Tidal Signal
#
#
# Over the course of 10 days (90 profiles) in January of 2024 we see variation in starting depth
# and end depth for the Oregon Slope Base shallow profiler.

# %%
# %matplotlib inline
# %run ~/argosy/TimeSeriesProfileCorrelation.py
# Out:
# TimeSeriesProfileCorrelation
#   Source: /home/rob/ooi/postproc/pp06
#   Time range: 2024-01-01 to 2024-01-11
#   Depth grid: 27-185m, step=0.04m
#
#   Processing temperature...
#     90 profiles in range
#     89 offset values computed
#
#   Processing salinity...
#     90 profiles in range
#     89 offset values computed
# Saved: /home/rob/ooi/visualizations/TidalSignal.png
#
# === Start depth vs Tidal height cross-correlation ===
#   Forward shift peak:  lag = +6.17 hours, correlation = 0.3668
#   Backward shift peak: lag = -5.33 hours, correlation = 0.6098
#
#   Best match: shift tidal signal BACKWARD by 5.33 hours (r=0.6098)
#   (Positive lag = tide leads start depth; negative lag = tide lags start depth)
