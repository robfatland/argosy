# %% [markdown]
# # Data Streamline
#
#
# This code reduces datasets from original format to a much smaller minimalist version intended
# for analysis.

# %% [markdown]
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150101T173429.059605-20150205T145959.761242.nc

# %%
# Filename transformer

# sourcefnm:
#   'deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150101T173429.059605-20150205T145959.761242.nc'
# breakdown:
# deployment00NN + _ + RS01SBPS + -SF01A + -3C + -PARADA101 + -streamed-parad_sa_sample + 
#   _ + YYYYMMDDThhmmss.ssssss + - + YYYYMMDDThhmmss.ssssss + .nc
# becomes:
# ooi_rca_sb_sp_par_str_alg01_prod01_d01_YYYYMMDDThhmmss_YYYYMMDDThhmmss.nc
