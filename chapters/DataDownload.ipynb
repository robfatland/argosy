# %% [markdown]
# # Data Download
#
#
# This notebook deals with transferring datasets from OOINET (and possibly other
# resources such as the PO-DAAC) to localhost.

# %%
import requests
from bs4 import BeautifulSoup
import os
from pathlib import Path

def download_ooi_data(download_link, target_folder):

    # expand target folder to full path if it uses ~
    target_folder = os.path.expanduser(target_folder)
    
    # Create folder if it doesn't exist
    Path(target_folder).mkdir(parents=True, exist_ok=True)
    
    # Get directory listing
    response = requests.get(download_link)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all file links (exclude directories ending with /)
    files = []
    for link in soup.find_all('a'):
        href = link.get('href')
        if href and not href.startswith('?') and href != '../' and not href.endswith('/'):
            files.append(href)
    
    # Get file sizes - Initial Download Manifest
    file_info = []
    total_size = 0
    nc_files = []
    
    for filename in files:
        file_url = f"{download_link.rstrip('/')}/{filename}"
        head = requests.head(file_url)
        size = int(head.headers.get('content-length', 0))
        file_info.append((filename, size))
        total_size += size
        
        if filename.endswith('.nc'):
            nc_files.append((filename, size))
    
    # Print initial statistics
    print(f"Total files: {len(files)}")
    print(f"Total data volume: {total_size / (1024**3):.2f} GB")
    
    if nc_files:
        mean_nc_size = sum(s for _, s in nc_files) / len(nc_files)
        print(f"NetCDF files: {len(nc_files)}")
        print(f"Mean NetCDF file size: {mean_nc_size / (1024**2):.2f} MB")
    
    # Modify Download Manifest
    userskip = input("\nSkip CTD files? (y/n): ")
    if userskip.lower() != "n":
        file_info = [(f, s) for f, s in file_info if not ('ctdpf' in f or 'CTDPF' in f)]
        print(f"Removed CTD files from manifest")
    
    # Print final statistics
    final_size = sum(s for _, s in file_info)
    print(f"\nFinal Download Manifest:")
    print(f"Total files: {len(file_info)}")
    print(f"Total data volume: {final_size / (1024**3):.2f} GB")
    
    # Confirm download
    confirm = input("\nProceed with download? (y/n): ")
    if confirm.lower() != 'y':
        print("Download cancelled")
        return

    print("\n\n\n\n")
    print(file_info)
    print("\n\n\n\n")


    # Download files
    for filename, size in file_info:
        file_url = f"{download_link.rstrip('/')}/{filename}"
        target_path = os.path.join(target_folder, filename)
        print("filename is \n\n")
        print(filename)
        print("\n\nfile_url is \n\n")
        print(file_url)
        print("\n\n\ntarget_path is \n\n")
        print(target_path)
        
        print(f"Downloading {filename} ({size / (1024**2):.2f} MB)...")
        
        r = requests.get(file_url, stream=True)
        with open(target_path, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)
    
    print(f"\nDownload complete. Files saved to {target_folder}")

if __name__ == "__main__":
    # download_link = input("Enter download link: ")
    download_link = "https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample"
    # target_folder = input("Enter target folder path: ")
    target_folder = "/home/rob/ooidata/rca/sb/scalar/2015_2025_par"
    download_ooi_data(download_link, target_folder)
# Out:
# Total files: 155
# Total data volume: 70.86 GB
# NetCDF files: 125
# Mean NetCDF file size: 580.45 MB
# Skip CTD files? (y/n):  y
# Removed CTD files from manifest
#
# Final Download Manifest:
# Total files: 110
# Total data volume: 55.41 GB
# Proceed with download? (y/n):  y
# [('deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml', 2185), ('deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150101T173429.059605-20150205T145959.761242.nc', 691440176), ('deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150205T150000.053521-20150312T025959.778731.nc', 690818270), ('deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150312T030000.060683-20150421T145959.885758.nc', 688910602), ('deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150421T150000.167701-20150524T145959.808200.nc', 690762066), ('deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150524T150000.100172-20150628T085959.734947.nc', 692086824), ('deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150628T090000.027704-20150705T235959.767406.nc', 158898090), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml', 3292), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150708T221917.578026-20150811T025959.824384.nc', 689246475), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150811T030000.115061-20150913T085959.991434.nc', 688027350), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150913T090000.282226-20151015T205959.718259.nc', 687988340), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151015T210000.009144-20151125T145959.906267.nc', 680681247), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151125T150000.197055-20151227T205959.758392.nc', 680086566), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151227T210000.038965-20160129T025959.941332.nc', 683195007), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160129T030000.221962-20160301T085959.878225.nc', 678904494), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160301T090000.158608-20160402T145959.988397.nc', 681132177), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160402T150000.268780-20160504T205959.953049.nc', 685814182), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160504T210000.244038-20160606T085959.793479.nc', 681887070), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160606T090000.073956-20160708T085959.726502.nc', 680810161), ('deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160708T090000.007061-20160716T111050.216115.nc', 168798332), ('deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml', 2189), ('deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160718T175353.432728-20160821T025959.765650.nc', 685994613), ('deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160821T030000.057773-20160922T205959.860240.nc', 684954761), ('deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160922T210000.142761-20161025T085959.993051.nc', 681792884), ('deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161025T090000.275422-20161126T205959.891838.nc', 682306750), ('deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161126T210000.174750-20161229T085959.864172.nc', 683084057), ('deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161229T090000.147614-20170130T014303.508888.nc', 639137403), ('deployment0004_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml', 2371), ('deployment0004_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20170804T200110.101331-20170906T025959.806603.nc', 684221872), ('deployment0004_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20170906T030000.086983-20171008T085959.816464.nc', 684656163), ('deployment0004_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20171008T090000.106357-20171109T025959.720665.nc', 677423848), ('deployment0004_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20 ...
#
#
#
#
#
# filename is
#
#
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
# Downloading deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml (0.00 MB)...
# filename is
#
#
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150101T173429.059605-20150205T145959.761242.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150101T173429.059605-20150205T145959.761242.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150101T173429.059605-20150205T145959.761242.nc
# Downloading deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150101T173429.059605-20150205T145959.761242.nc (659.41 MB)...
# filename is
#
#
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150205T150000.053521-20150312T025959.778731.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150205T150000.053521-20150312T025959.778731.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150205T150000.053521-20150312T025959.778731.nc
# Downloading deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150205T150000.053521-20150312T025959.778731.nc (658.82 MB)...
# filename is
#
#
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150312T030000.060683-20150421T145959.885758.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150312T030000.060683-20150421T145959.885758.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150312T030000.060683-20150421T145959.885758.nc
# Downloading deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150312T030000.060683-20150421T145959.885758.nc (657.00 MB)...
# filename is
#
#
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150421T150000.167701-20150524T145959.808200.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150421T150000.167701-20150524T145959.808200.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150421T150000.167701-20150524T145959.808200.nc
# Downloading deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150421T150000.167701-20150524T145959.808200.nc (658.76 MB)...
# filename is
#
#
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150524T150000.100172-20150628T085959.734947.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150524T150000.100172-20150628T085959.734947.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150524T150000.100172-20150628T085959.734947.nc
# Downloading deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150524T150000.100172-20150628T085959.734947.nc (660.03 MB)...
# filename is
#
#
# deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150628T090000.027704-20150705T235959.767406.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150628T090000.027704-20150705T235959.767406.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150628T090000.027704-20150705T235959.767406.nc
# Downloading deployment0001_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150628T090000.027704-20150705T235959.767406.nc (151.54 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml (0.00 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150708T221917.578026-20150811T025959.824384.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150708T221917.578026-20150811T025959.824384.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150708T221917.578026-20150811T025959.824384.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150708T221917.578026-20150811T025959.824384.nc (657.32 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150811T030000.115061-20150913T085959.991434.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150811T030000.115061-20150913T085959.991434.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150811T030000.115061-20150913T085959.991434.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150811T030000.115061-20150913T085959.991434.nc (656.15 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150913T090000.282226-20151015T205959.718259.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150913T090000.282226-20151015T205959.718259.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150913T090000.282226-20151015T205959.718259.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20150913T090000.282226-20151015T205959.718259.nc (656.12 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151015T210000.009144-20151125T145959.906267.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151015T210000.009144-20151125T145959.906267.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151015T210000.009144-20151125T145959.906267.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151015T210000.009144-20151125T145959.906267.nc (649.15 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151125T150000.197055-20151227T205959.758392.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151125T150000.197055-20151227T205959.758392.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151125T150000.197055-20151227T205959.758392.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151125T150000.197055-20151227T205959.758392.nc (648.58 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151227T210000.038965-20160129T025959.941332.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151227T210000.038965-20160129T025959.941332.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151227T210000.038965-20160129T025959.941332.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20151227T210000.038965-20160129T025959.941332.nc (651.55 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160129T030000.221962-20160301T085959.878225.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160129T030000.221962-20160301T085959.878225.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160129T030000.221962-20160301T085959.878225.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160129T030000.221962-20160301T085959.878225.nc (647.45 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160301T090000.158608-20160402T145959.988397.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160301T090000.158608-20160402T145959.988397.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160301T090000.158608-20160402T145959.988397.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160301T090000.158608-20160402T145959.988397.nc (649.58 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160402T150000.268780-20160504T205959.953049.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160402T150000.268780-20160504T205959.953049.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160402T150000.268780-20160504T205959.953049.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160402T150000.268780-20160504T205959.953049.nc (654.04 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160504T210000.244038-20160606T085959.793479.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160504T210000.244038-20160606T085959.793479.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160504T210000.244038-20160606T085959.793479.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160504T210000.244038-20160606T085959.793479.nc (650.30 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160606T090000.073956-20160708T085959.726502.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160606T090000.073956-20160708T085959.726502.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160606T090000.073956-20160708T085959.726502.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160606T090000.073956-20160708T085959.726502.nc (649.27 MB)...
# filename is
#
#
# deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160708T090000.007061-20160716T111050.216115.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160708T090000.007061-20160716T111050.216115.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160708T090000.007061-20160716T111050.216115.nc
# Downloading deployment0002_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160708T090000.007061-20160716T111050.216115.nc (160.98 MB)...
# filename is
#
#
# deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml
# Downloading deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample.ncml (0.00 MB)...
# filename is
#
#
# deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160718T175353.432728-20160821T025959.765650.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160718T175353.432728-20160821T025959.765650.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160718T175353.432728-20160821T025959.765650.nc
# Downloading deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160718T175353.432728-20160821T025959.765650.nc (654.22 MB)...
# filename is
#
#
# deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160821T030000.057773-20160922T205959.860240.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160821T030000.057773-20160922T205959.860240.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160821T030000.057773-20160922T205959.860240.nc
# Downloading deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160821T030000.057773-20160922T205959.860240.nc (653.22 MB)...
# filename is
#
#
# deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160922T210000.142761-20161025T085959.993051.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160922T210000.142761-20161025T085959.993051.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160922T210000.142761-20161025T085959.993051.nc
# Downloading deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20160922T210000.142761-20161025T085959.993051.nc (650.21 MB)...
# filename is
#
#
# deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161025T090000.275422-20161126T205959.891838.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161025T090000.275422-20161126T205959.891838.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161025T090000.275422-20161126T205959.891838.nc
# Downloading deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161025T090000.275422-20161126T205959.891838.nc (650.70 MB)...
# filename is
#
#
# deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161126T210000.174750-20161229T085959.864172.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161126T210000.174750-20161229T085959.864172.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161126T210000.174750-20161229T085959.864172.nc
# Downloading deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161126T210000.174750-20161229T085959.864172.nc (651.44 MB)...
# filename is
#
#
# deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161229T090000.147614-20170130T014303.508888.nc
#
#
# file_url is
#
#
# https://downloads.oceanobservatories.org/async_results/kilroy1618@gmail.com/20260103T003554734Z-RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161229T090000.147614-20170130T014303.508888.nc
#
#
#
# target_path is
#
#
# /home/rob/ooidata/rca/sb/scalar/2015_2025_par/deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161229T090000.147614-20170130T014303.508888.nc
# Downloading deployment0003_RS01SBPS-SF01A-3C-PARADA101-streamed-parad_sa_sample_20161229T090000.147614-20170130T014303.508888.nc (609.53 MB)...
